# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 2: Basic Python

# %% [markdown]
# ## Lab work 2.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із основними інструкціями Python;
# * ознайомитися із базовими алгоритмами;

# %% [markdown]
# ### Завдання 1

# %% [markdown]
# Для трьох введених натуральних чисел (користувач вводить числа через пробіл) знайдіть мінімальне та максимальне

# %%
n = input('input sombth ')
n=n.split(' ')
n=[int(i) for i in n]
n

print(f"Минимум: {min(n)}, максимум:{max(n)}")
# Out:
# input sombth21321 554 2 1 55
# Минимум: 1, максимум:21321

# %% [markdown]
# ### Завдання 2

# %% [markdown]
# Програма приймає на вхід два параметри: стать спортсмена(`sex = (f, m)`) та вік спортсмена(`age = [0,100]`).  Спортсмен-дівчина може брати участь у змаганні, якщо її вік більший 18, спортсмен-хлопець - якщо вік більший 16
#
# Якщо введеніть не коректні дані, виведіть повідомлення про помилку

# %%
sexy=['m','f','male','female']
while True:
    try:
        sex = str(input('Input m or male if yoyr gender is male and f or female if female: '))
        age = float(input('How old? '))
    except ValueError:
        print('Дані некоретні.')
        continue
    if not sex in sexy:
        raise Exception("Gender is not defined.")
    if age<0 or age >100:
        raise Exception("Too old, sorry!")
    else:
        if (sex == 'm' or sex == 'male') and (age > 16 and age < 100):
            print('this guy is in competition')
            break
        elif (sex == 'f' or sex == 'female') and (age > 18 and age < 100):
            print('this gurl is in competition')
            break
        else:
            print('This man or woman cant take part in this competition.')
            break
# Out:
# Input m or male if yoyr gender is male and f or female if female: man
# How old? 25
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-30-8198f29f4856> in <module>
#       8         continue
#       9     if not sex in sexy:
# ---> 10         raise Exception("Gender is not defined.")
#      11     if age<0 or age >100:
#      12         raise Exception("Too old, sorry!")
#
# Exception: Gender is not defined.

# %% [markdown]
# ### Завдання 3

# %% [markdown]
# Для введеного натурального числа побудуйте драбинку.
#
# Наприклад, якщо N = 5, драбинка буде мати вигляд:
#
# &
#
# &&
#
# &&&
#
# &&&&
#
# &&&&&

# %%
N = int(input())
for i in range(N):
    print(str('&')*i)
# Out:
# 10
#
# &
# &&
# &&&
# &&&&
# &&&&&
# &&&&&&
# &&&&&&&
# &&&&&&&&
# &&&&&&&&&

# %% [markdown]
# ### Завдання 4

# %% [markdown]
# Із заданого речення виведіть кожне слово і його довжину

# %%
sentence = 'My favourite tutor in academy is Ihor'
sentence=sentence.split(' ')
mathway={str(k):len(k) for k in sentence}
#type(mathway)
mathway
for a,b in mathway.items():
    print(a,b)
# Out:
# My 2
# favourite 9
# tutor 5
# in 2
# academy 7
# is 2
# Ihor 4

# %% [markdown]
# ### Завдання 5

# %% [markdown]
# Для заданого тексту реалізуйте:
# * Знайдіть кількість слів
# * Знайдіть кількість унікальних слів
# * Своірть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
# * Виведіть топ-3 слів, що найчастіше зустрічаються
#
# Вважаємо, що слово це стрічка з трьох і більше букв, очищена від знаків пунктуації

# %%
text = """До чого ж гарно і весело було в нашому горóді! Ото як вийти з сіней та подивись навколо — геть-чисто все зелене та буйне. А сад було як зацвіте весною! А що робилось на початку літа — огірки цвітуть, гарбузи цвітуть, картопля цвіте. Цвіте малина, смородина, тютюн, квасоля. А соняшника, а маку, буряків, лободи, укропу, моркви! Чого тільки не насадить наша невгамовна мати.

— Нічого в світі так я не люблю, як саджати що-небудь у землю, щоб проізростало. Коли вилізає з землі всяка рослиночка, ото мені радість,— любила проказувати вона.

Город до того переповнявсь рослинами, що десь серед літа вони вже не вміщалися в ньому. Вони лізли одна на одну, переплітались, душились, дерлися на хлів, на стріху, повзли на тин, а гарбузи звисали з тину прямо на вулицю.

А малини — красної, білої! А вишень, а груш солодких, було. як наїсися,— цілий день живіт як бубон.

І росло ще, пригадую, багато тютюну, в якому ми, маленькі, ходили, мов у лісі, в якому пізнали перші мозолі на дитячих руках.

А вздовж тину, за старою повіткою, росли великі кущі смородини, бузини і ще якихось невідомих рослин. Там неслися кури нишком од матері і різне дрібне птаство. Туди ми рідко лазили. Там було темно навіть удень, і ми боялись гадюки. Хто з нас у дитинстві не боявся гадюки, так за все життя й не побачивши її ніде?

Коло хати, що стояла в саду, цвіли квіти, а за хатою, проти сінешніх дверей, коло вишень,— поросла полином стара погребня з одкритою лядою, звідки завжди пахло цвіллю. Там, у льоху, в присмерку плигали жаби. Напевно, там водилися й гадюки.

На погребні любив спати дід.

У нас був дід дуже схожий на бога. Коли я молився богу, я завжди бачив на покуті портрет діда в старих срібнофольгових шатах, а сам дід лежав на печі і тихо кашляв, слухаючи своїх молитов.

У неділю перед богами горіла маленька синенька лампадка, в яку завжди набиралось повно мух. Образ святого Миколая також був схожий на діда, особливо коли дід часом підстригав собі бороду і випивав перед обідом чарку горілки з перцем, і мати не лаялась. Святий Федосій більш скидався на батька. Федосію я не молився, в нього була ще темна борода, а в руці гирлига, одягнена чомусь у білу хустку. А от бог, схожий на діда, той тримав в одній руці круглу сільничку, а трьома пýчками другої неначе збирався взяти зубок часнику
Звали нашого діда, як я вже потім довідавсь, Семеном. Він був високий і худий, і чоло в нього високе, хвилясте довге волосся сиве, а борода біла. І була в нього велика грижа ще з молодих чумацьких літ. Пахнув дід теплою землею і трохи млином. Він був письменний по-церковному і в неділю любив урочисто читати псалтир. Ні дід, ні ми не розуміли прочитаного, і це завжди хвилювало нас, як дивна таємниця, що надавала прочитаному особливого, небуденного смислу.

Мати ненавиділа діда і вважала його за чорнокнижника. Ми не вірили матері і захищали діда од її нападів, бо псалтир всередині був не чорний, а білий, а товста шкіряна палітурка — коричнева, як гречаний мед чи стара халява. Зрештою, мати крадькома таки знищила псалтир. Вона спалила його в печі по одному листочку, боячись палити зразу весь, щоб він часом не вибухнув і не розніс печі.

Любив дід гарну бесіду й добре слово. Часом по дорозі на луг, коли хто питав у нього дорогу на Борзну чи на Батурин, він довго стояв посеред шляху і, махаючи пужалном, гукав услід подорожньому:

— Прямо, та й прямо, та й прямо, та й нікуди ж не звертайте!.. Добра людина поїхала, дай їй бог здоров'я,— зітхав він лагідно, коли подорожній нарешті зникав у кущах.

— А хто вона, діду, людина ота? Звідки вона?

— А бог її знає, хіба я знаю... Ну, чого стоїш як укопаний? — звертався дід до коня, сідаючи на воза.— Но, трогай-бо, ну...

Він був наш добрий дух лугу і риби. Гриби й ягоди збирав він у лісі краще за нас усіх і розмовляв з кіньми, з телятами, з травами, з старою грушею і дубом — з усім живим, що росло і рухалось навколо.
Більш за все на світі любив дід сонце. Він прожив під сонцем коло ста літ, ніколи не ховаючись у холодок. Так під сонцем на погребні, коло яблуні, він і помер, коли прийшов його час.

Дід любив кашляти. Кашляв він часом так довго й гучно, що скільки ми не старалися, ніхто не міг його як слід передражнити. Його кашель чув увесь куток. Старі люди по дідовому кашлю вгадували навіть погоду.
"""

# %%
text1=text.replace(',',' ,').replace('.',' .').replace('!',' !').replace('?',' ?').replace('\n',' ').replace(':',' :')
text2=text1.split()
text2_q=[i for i in text2 if not len(i)<3]
print(f"Знайдіть кількість слів: {len(text2_q)} штук.")
N=list(set(text2))
N=[i for i in N if not len(i)<3]
print(f"Знайдіть кількість унікальних слів: {len(N)} штук.")
D={str(i) : text2_q.count(i) for i in N}
print('Створіть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті')
for a,b in D.items():
    print(f"{a} : {b}")
D_V={k: v for k, v in sorted(D.items(),reverse=True, key=lambda item: item[1])}#сортированный по знач
dvt=tuple(D_V)
print('Виведіть топ-3 слів, що найчастіше зустрічаються')   
for i in range(3):
    key=list(D_V)[i]
    print(f"{i+1} позиція '{key}', входжень: {D_V[key]}")
# Out:
# Знайдіть кількість слів: 537 штук.
# Знайдіть кількість унікальних слів: 433 штук.
# Створіть словник, де ключе буде слово із тексту, значенням - частота зустрічання в тексті
# саду : 1
# святого : 1
# яку : 1
# чорний : 1
# там : 1
# слово : 1
# наша : 1
# услід : 1
# Він : 4
# здоров'я : 1
# бачив : 1
# прожив : 1
# люди : 1
# багато : 1
# добре : 1
# горóді : 1
# прочитаного : 1
# кашель : 1
# холодок : 1
# Звідки : 1
# краще : 1
# Його : 1
# матері : 2
# звисали : 1
# повіткою : 1
# квасоля : 1
# пахло : 1
# мозолі : 1
# печі : 3
# халява : 1
# куток : 1
# землі : 1
# він : 6
# перші : 1
# Зрештою : 1
# побачивши : 1
# Семеном : 1
# чорнокнижника : 1
# Кашляв : 1
# лядою : 1
# буряків : 1
# малина : 1
# псалтир : 3
# бузини : 1
# малини : 1
# ньому : 1
# подивись : 1
# коло : 3
# прийшов : 1
# батька : 1
# Борзну : 1
# нікуди : 1
# яблуні : 1
# нашому : 1
# неначе : 1
# дрібне : 1
# усіх : 1
# геть-чисто : 1
# надавала : 1
# повзли : 1
# вишень : 2
# кущах : 1
# гарну : 1
# переплітались : 1
# хлів : 1
# руці : 2
# велика : 1
# подорожньому : 1
# пужалном : 1
# саджати : 1
# Хто : 1
# хто : 2
# Коло : 1
# бога : 1
# довідавсь : 1
# волосся : 1
# цілий : 1
# робилось : 1
# горіла : 1
# схожий : 3
# звідки : 1
# одній : 1
# стоїш : 1
# нашого : 1
# сад : 1
# проти : 1
# чумацьких : 1
# сіней : 1
# знаю : 1
# той : 1
# землею : 1
# Прямо : 1
# ховаючись : 1
# Вони : 1
# моркви : 1
# слухаючи : 1
# горілки : 1
# сиве : 1
# буйне : 1
# махаючи : 1
# питав : 1
# потім : 1
# переповнявсь : 1
# взяти : 1
# що-небудь : 1
# дверей : 1
# любила : 1
# його : 4
# росли : 1
# спати : 1
# Коли : 2
# бесіду : 1
# тихо : 1
# неділю : 2
# вони : 1
# рослин : 1
# трьома : 1
# старих : 1
# неслися : 1
# стояла : 1
# дух : 1
# ніколи : 1
# Звали : 1
# Там : 3
# цвіте : 1
# проказувати : 1
# маку : 1
# присмерку : 1
# смислу : 1
# красної : 1
# сідаючи : 1
# набиралось : 1
# руках : 1
# Напевно : 1
# цвіллю : 1
# тільки : 1
# знає : 1
# розмовляв : 1
# вилізає : 1
# льоху : 1
# одкритою : 1
# сонце : 1
# час : 1
# спалила : 1
# кашлю : 1
# Так : 1
# був : 6
# скидався : 1
# лампадка : 1
# нас : 4
# письменний : 1
# гарбузи : 2
# мати : 3
# рідко : 1
# наїсися : 1
# великі : 1
# маленькі : 1
# високе : 1
# особливо : 1
# Федосію : 1
# трохи : 1
# боячись : 1
# зітхав : 1
# більш : 1
# дивна : 1
# шкіряна : 1
# високий : 1
# полином : 1
# гадюки : 3
# мед : 1
# часнику : 1
# покуті : 1
# одну : 1
# травами : 1
# росло : 2
# літ : 2
# мух : 1
# якихось : 1
# Нічого : 1
# гречаний : 1
# зразу : 1
# невгамовна : 1
# таки : 1
# збирав : 1
# Федосій : 1
# душились : 1
# укопаний : 1
# старою : 2
# любив : 4
# живим : 1
# всяка : 1
# передражнити : 1
# білий : 1
# того : 1
# Миколая : 1
# вірили : 1
# була : 2
# дорогу : 1
# бог : 3
# чоло : 1
# телятами : 1
# ненавиділа : 1
# лугу : 1
# також : 1
# обідом : 1
# люблю : 1
# ста : 1
# лежав : 1
# ягоди : 1
# риби : 1
# пізнали : 1
# погребні : 2
# було : 4
# одягнена : 1
# тин : 1
# шатах : 1
# поросла : 1
# тютюну : 1
# діда : 6
# богами : 1
# рухалось : 1
# ото : 1
# другої : 1
# Город : 1
# вздовж : 1
# подорожній : 1
# вийти : 1
# хустку : 1
# смородина : 1
# лободи : 1
# весною : 1
# худий : 1
# Часом : 1
# помер : 1
# навіть : 2
# Гриби : 1
# гарно : 1
# рослиночка : 1
# лісі : 2
# теплою : 1
# дід : 9
# сінешніх : 1
# старалися : 1
# погоду : 1
# коня : 1
# зелене : 1
# ходили : 1
# різне : 1
# хіба : 1
# небуденного : 1
# землю : 1
# проізростало : 1
# молився : 2
# міг : 1
# одному : 1
# літа : 2
# Святий : 1
# пýчками : 1
# наш : 1
# стара : 2
# день : 1
# світі : 2
# підстригав : 1
# все : 3
# збирався : 1
# звертайте : 1
# боялись : 1
# зубок : 1
# білої : 1
# тримав : 1
# дідовому : 1
# шляху : 1
# скільки : 1
# Добра : 1
# трогай-бо : 1
# цвіли : 1
# дуже : 1
# Чого : 1
# Ото : 1
# лазили : 1
# смородини : 1
# гукав : 1
# людина : 2
# вгадували : 1
# прочитаному : 1
# цвітуть : 2
# Мати : 1
# початку : 1
# так : 3
# захищали : 1
# Вона : 1
# кіньми : 1
# діду : 1
# товста : 1
# солодких : 1
# дитинстві : 1
# темно : 1
# нарешті : 1
# водилися : 1
# вважала : 1
# радість : 1
# зацвіте : 1
# листочку : 1
# Більш : 1
# увесь : 1
# якому : 2
# палітурка : 1
# зникав : 1
# одна : 1
# особливого : 1
# груш : 1
# вулицю : 1
# нишком : 1
# плигали : 1
# розніс : 1
# борода : 2
# богу : 1
# рослинами : 1
# білу : 1
# насадить : 1
# Старі : 1
# грушею : 1
# вона : 3
# удень : 1
# слід : 1
# добрий : 1
# сільничку : 1
# луг : 1
# нього : 4
# пригадую : 1
# чарку : 1
# птаство : 1
# круглу : 1
# посеред : 1
# тютюн : 1
# мені : 1
# весело : 1
# кашляв : 1
# Пахнув : 1
# знищила : 1
# довго : 2
# грижа : 1
# стріху : 1
# воза : 1
# картопля : 1
# прямо : 3
# хвилясте : 1
# лагідно : 1
# весь : 1
# бубон : 1
# перед : 2
# темна : 1
# млином : 1
# Цвіте : 1
# мов : 1
# Батурин : 1
# лаялась : 1
# під : 2
# живіт : 1
# хати : 1
# бороду : 1
# повно : 1
# Дід : 1
# ніде : 1
# сам : 1
# усім : 1
# лізли : 1
# соняшника : 1
# дубом : 1
# жаби : 1
# боявся : 1
# біла : 1
# читати : 1
# життя : 1
# таємниця : 1
# коли : 4
# урочисто : 1
# дай : 1
# маленька : 1
# вміщалися : 1
# кури : 1
# невідомих : 1
# огірки : 1
# собі : 1
# розуміли : 1
# завжди : 4
# кущі : 1
# синенька : 1
# молодих : 1
# хатою : 1
# дорозі : 1
# навколо : 2
# довге : 1
# ніхто : 1
# тину : 2
# хвилювало : 1
# кашляти : 1
# гирлига : 1
# всередині : 1
# своїх : 1
# часом : 3
# по-церковному : 1
# дерлися : 1
# стояв : 1
# погребня : 1
# перцем : 1
# крадькома : 1
# чого : 2
# укропу : 1
# квіти : 1
# палити : 1
# молитов : 1
# серед : 1
# Образ : 1
# чомусь : 1
# срібнофольгових : 1
# гучно : 1
# нападів : 1
# ота : 1
# десь : 1
# щоб : 2
# поїхала : 1
# коричнева : 1
# звертався : 1
# вже : 2
# чув : 1
# випивав : 1
# сонцем : 2
# портрет : 1
# Любив : 1
# Туди : 1
# вибухнув : 1
# дитячих : 1
# Виведіть топ-3 слів, що найчастіше зустрічаються
# 1 позиція 'дід', входжень: 9
# 2 позиція 'він', входжень: 6
# 3 позиція 'був', входжень: 6

# %% [markdown]
# ### Завдання 6

# %% [markdown]
# Напишіть функції, що:
# * рохраховує мінімальне та максимальне значення
# * середнє значення послідовності
# * медіану послідовності
# * частоту кожної цифри в послідовності
# * середнє квадратичне відхилення
#
# Послідовність чисел ганеруємо рандомно

# %%
import random

#генеруэмо тисячу чисел в діапазоні від 0 до 10 100 мабуть
list_with_random_numbers = [random.randint(0,100) for i in range(1000)]
list_with_random_numbers
def median(l):
    l.sort()
    half = len(l) // 2
    if not len(l) % 2:
        return (l[half - 1] + l[half]) / 2.0
    return l[half]
def standart(l):
    le=len(l)
    mean=sum(l)/len(l)
    std=(sum([(i-mean)**2 for i in l])/(le-1))**0.5
    return std
    
print(f"Мінімум: {min(list_with_random_numbers)}, Максимум: {max(list_with_random_numbers)}, Average: {sum(list_with_random_numbers)/len(list_with_random_numbers)}, Median: {median(list_with_random_numbers)}, Stand. deviation: {round(standart(list_with_random_numbers),2)}")
N=set(list_with_random_numbers)
fun=list()
for i in N:
    print(f"Для {i}, входжень: {list_with_random_numbers.count(i)}")
    fun.append(list_with_random_numbers.count(i))

    
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.displot(data=list_with_random_numbers)
#plt.show()
# Out:
# Мінімум: 0, Максимум: 100, Average: 49.362, Median: 49.0, Stand. deviation: 29.05
# Для 0, входжень: 9
# Для 1, входжень: 9
# Для 2, входжень: 6
# Для 3, входжень: 5
# Для 4, входжень: 8
# Для 5, входжень: 15
# Для 6, входжень: 11
# Для 7, входжень: 6
# Для 8, входжень: 6
# Для 9, входжень: 19
# Для 10, входжень: 17
# Для 11, входжень: 16
# Для 12, входжень: 10
# Для 13, входжень: 6
# Для 14, входжень: 7
# Для 15, входжень: 8
# Для 16, входжень: 14
# Для 17, входжень: 5
# Для 18, входжень: 12
# Для 19, входжень: 16
# Для 20, входжень: 10
# Для 21, входжень: 9
# Для 22, входжень: 12
# Для 23, входжень: 10
# Для 24, входжень: 8
# Для 25, входжень: 10
# Для 26, входжень: 11
# Для 27, входжень: 13
# Для 28, входжень: 9
# Для 29, входжень: 12
# Для 30, входжень: 10
# Для 31, входжень: 15
# Для 32, входжень: 10
# Для 33, входжень: 9
# Для 34, входжень: 12
# Для 35, входжень: 8
# Для 36, входжень: 11
# Для 37, входжень: 3
# Для 38, входжень: 4
# Для 39, входжень: 15
# Для 40, входжень: 13
# Для 41, входжень: 10
# Для 42, входжень: 14
# Для 43, входжень: 14
# Для 44, входжень: 5
# Для 45, входжень: 5
# Для 46, входжень: 7
# Для 47, входжень: 15
# Для 48, входжень: 7
# Для 49, входжень: 8
# Для 50, входжень: 6
# Для 51, входжень: 5
# Для 52, входжень: 9
# Для 53, входжень: 11
# Для 54, входжень: 15
# Для 55, входжень: 12
# Для 56, входжень: 7
# Для 57, входжень: 14
# Для 58, входжень: 10
# Для 59, входжень: 12
# Для 60, входжень: 11
# Для 61, входжень: 9
# Для 62, входжень: 8
# Для 63, входжень: 9
# Для 64, входжень: 7
# Для 65, входжень: 16
# Для 66, входжень: 16
# Для 67, входжень: 6
# Для 68, входжень: 7
# Для 69, входжень: 8
# Для 70, входжень: 11
# Для 71, входжень: 10
# Для 72, входжень: 11
# Для 73, входжень: 9
# Для 74, входжень: 10
# Для 75, входжень: 10
# Для 76, входжень: 7
# Для 77, входжень: 11
# Для 78, входжень: 9
# Для 79, входжень: 10
# Для 80, входжень: 15
# Для 81, входжень: 9
# Для 82, входжень: 7
# Для 83, входжень: 13
# Для 84, входжень: 8
# Для 85, входжень: 11
# Для 86, входжень: 9
# Для 87, входжень: 7
# Для 88, входжень: 8
# Для 89, входжень: 5
# Для 90, входжень: 9
# Для 91, входжень: 11
# Для 92, входжень: 4
# Для 93, входжень: 12
# Для 94, входжень: 11
# Для 95, входжень: 8
# Для 96, входжень: 8
# Для 97, входжень: 8
# Для 98, входжень: 13
# Для 99, входжень: 13
# Для 100, входжень: 11
